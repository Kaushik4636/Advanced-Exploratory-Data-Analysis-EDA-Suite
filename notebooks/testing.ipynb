# %%
import pandas as pd
import sys
sys.path.append("../src")
from eda import EDASuite

# Load dataset
df = pd.read_csv("../data/sample.csv")

# Initialize EDA suite
eda = EDASuite(df)

# Summary stats
print("Summary Statistics:\n", eda.summary_stats())

# Missing values
print("\nMissing Values:\n", eda.missing_values())

# Correlation
print("\nCorrelation Matrix:\n", eda.correlations())

# Generate plots
eda.plot_histograms()
eda.plot_correlation_heatmap()
print("\nPlots saved in 'plots/' folder")
# Out:
# Summary Statistics:
#          count          mean          std      min       25%      50%  \
# age       6.0     28.833333     4.875107     22.0     25.75     29.0
# income    6.0  53333.333333  5501.514943  45000.0  50500.00  53500.0
# score     6.0    206.666667    10.801234    190.0    201.25    207.5
#
#              75%      max
# age        32.25     35.0
# income  57250.00  60000.0
# score     213.75    220.0
#
# Missing Values:
#  age       0
# income    0
# gender    0
# score     0
# dtype: int64
#
# Correlation Matrix:
#               age    income     score
# age     1.000000  0.994265  0.803942
# income  0.994265  1.000000  0.796547
# score   0.803942  0.796547  1.000000
#
# Plots saved in 'plots/' folder
